# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
img = Image.open(r'C:\Users\s jaswanth reddy\OneDrive\Desktop\eleohant.jpeg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr=np.asanyarray(img) # convert image to array 
img_arr
# Out:
# array([[[123, 174, 239],
#         [124, 175, 240],
#         [124, 175, 240],
#         ...,
#         [118, 168, 237],
#         [118, 168, 237],
#         [118, 168, 237]],
#
#        [[123, 174, 239],
#         [123, 174, 239],
#         [124, 175, 240],
#         ...,
#         [118, 168, 237],
#         [118, 168, 237],
#         [118, 168, 237]],
#
#        [[123, 174, 239],
#         [123, 174, 239],
#         [123, 174, 239],
#         ...,
#         [118, 168, 237],
#         [118, 168, 237],
#         [118, 168, 237]],
#
#        ...,
#
#        [[153, 111,  51],
#         [167, 125,  65],
#         [185, 144,  82],
#         ...,
#         [157, 118,  53],
#         [151, 112,  47],
#         [146, 107,  42]],
#
#        [[155, 117,  52],
#         [172, 134,  69],
#         [186, 148,  83],
#         ...,
#         [162, 124,  59],
#         [156, 118,  53],
#         [149, 111,  46]],
#
#        [[155, 117,  52],
#         [172, 134,  69],
#         [186, 148,  83],
# ...

# %%
img_arr.shape
# Out:
# (194, 259, 3)

# %%
plt.imshow(img_arr)

# %%
img_red=img_arr.copy()
img_red
# Out:
# array([[[123, 174, 239],
#         [124, 175, 240],
#         [124, 175, 240],
#         ...,
#         [118, 168, 237],
#         [118, 168, 237],
#         [118, 168, 237]],
#
#        [[123, 174, 239],
#         [123, 174, 239],
#         [124, 175, 240],
#         ...,
#         [118, 168, 237],
#         [118, 168, 237],
#         [118, 168, 237]],
#
#        [[123, 174, 239],
#         [123, 174, 239],
#         [123, 174, 239],
#         ...,
#         [118, 168, 237],
#         [118, 168, 237],
#         [118, 168, 237]],
#
#        ...,
#
#        [[153, 111,  51],
#         [167, 125,  65],
#         [185, 144,  82],
#         ...,
#         [157, 118,  53],
#         [151, 112,  47],
#         [146, 107,  42]],
#
#        [[155, 117,  52],
#         [172, 134,  69],
#         [186, 148,  83],
#         ...,
#         [162, 124,  59],
#         [156, 118,  53],
#         [149, 111,  46]],
#
#        [[155, 117,  52],
#         [172, 134,  69],
#         [186, 148,  83],
# ...

# %%
img_arr==img_red
# Out:
# array([[[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        ...,
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
#         [ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True]],
#
#        [[ True,  True,  True],
#         [ True,  True,  True],
#         [ True,  True,  True],
#         ...,
# ...

# %%
plt.imshow(img_red)

# %%
img_red.shape
# Out:
# (194, 259, 3)

# %%
plt.imshow(img_red[:,:,0] )

# %%
img_red[:,:,0]
# Out:
# array([[123, 124, 124, ..., 118, 118, 118],
#        [123, 123, 124, ..., 118, 118, 118],
#        [123, 123, 123, ..., 118, 118, 118],
#        ...,
#        [153, 167, 185, ..., 157, 151, 146],
#        [155, 172, 186, ..., 162, 156, 149],
#        [155, 172, 186, ..., 162, 156, 149]], dtype=uint8)

# %%
 plt.imshow(img_red[:,:,0] , cmap='grey')

# %%
 plt.imshow(img_red[:,:,0] , cmap='Blues')

# %%
 plt.imshow(img_red[:,:,0] , cmap='Reds')

# %%
 plt.imshow(img_red[:,:,1] , cmap='grey')

# %%
 plt.imshow(img_red[:,:,2] , cmap='grey')

# %%
 plt.imshow(img_red[:,:,0] , cmap='grey')

# %%
img_red[:,:,0]=2

# %%
plt.imshow(img_red)

# %%
img1_blue=img_red.copy()

# %%
img1_blue[:,:,0]=0

# %%
plt.imshow(img1_blue)
